# %%
import pandas as pd

auto_price = pd.read_csv('Automobile price data _Raw_.csv')
# the file is downloaded from https://studio.azureml.net/ to the same folder where this notebook is stored, on C: drive.

# %%
auto_price.head(2)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...    engine-size  \
# 0  convertible          rwd           front        88.6  ...            130
# 1  convertible          rwd           front        88.6  ...            130
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
#
# [2 rows x 26 columns]

# %%
ap = auto_price
ap.head(2)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...    engine-size  \
# 0  convertible          rwd           front        88.6  ...            130
# 1  convertible          rwd           front        88.6  ...            130
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
#
# [2 rows x 26 columns]

# %%
print(ap['aspiration'])     # P. Series
ap[['make', 'aspiration']]  # P. DataFrame
# Out:
# 0        std
# 1        std
# 2        std
# 3        std
# 4        std
# 5        std
# 6        std
# 7        std
# 8      turbo
# 9      turbo
# 10       std
# 11       std
# 12       std
# 13       std
# 14       std
# 15       std
# 16       std
# 17       std
# 18       std
# 19       std
# 20       std
# 21       std
# 22       std
# 23     turbo
# 24       std
# 25       std
# 26       std
# 27     turbo
# 28       std
# 29     turbo
#        ...
# 175      std
# 176      std
# 177      std
# 178      std
# 179      std
# 180      std
# 181      std
# 182      std
# 183      std
# 184      std
# 185      std
# 186      std
# 187    turbo
# 188      std
# 189      std
# 190      std
# 191      std
# 192    turbo
# 193      std
# 194      std
# 195      std
# 196      std
# 197      std
# 198    turbo
# 199    turbo
# 200      std
# 201    turbo
# 202      std
# 203    turbo
# 204    turbo
# Name: aspiration, Length: 205, dtype: object
#             make aspiration
# ...

# %%
print(ap.ix[1, 'aspiration'])   
ap.ix[['make', 'aspiration']]  # ?
# Out:
# std
#             symboling normalized-losses make fuel-type aspiration  \
# make              NaN               NaN  NaN       NaN        NaN
# aspiration        NaN               NaN  NaN       NaN        NaN
#
#            num-of-doors body-style drive-wheels engine-location  wheel-base  \
# make                NaN        NaN          NaN             NaN         NaN
# aspiration          NaN        NaN          NaN             NaN         NaN
#
#             ...   engine-size  fuel-system  bore  stroke compression-ratio  \
# make        ...           NaN          NaN   NaN     NaN               NaN
# aspiration  ...           NaN          NaN   NaN     NaN               NaN
#
#            horsepower  peak-rpm city-mpg highway-mpg price
# make              NaN       NaN      NaN         NaN   NaN
# aspiration        NaN       NaN      NaN         NaN   NaN
#
# [2 rows x 26 columns]

# %%
ap.loc[1:5, 'aspiration']
# Out:
# 1    std
# 2    std
# 3    std
# 4    std
# 5    std
# Name: aspiration, dtype: object

# %%
ap.ix[1:5, 'aspiration']
# Out:
# 1    std
# 2    std
# 3    std
# 4    std
# 5    std
# Name: aspiration, dtype: object

# %%
ap.loc[ap['aspiration'] == 'std', 'make'].head()
# Out:
# 0    alfa-romero
# 1    alfa-romero
# 2    alfa-romero
# 3           audi
# 4           audi
# Name: make, dtype: object

# %%
ap.ix[ap['aspiration'] == 'std', 'make'].head()
# Out:
# 0    alfa-romero
# 1    alfa-romero
# 2    alfa-romero
# 3           audi
# 4           audi
# Name: make, dtype: object

# %%
ap.iloc[1:5]
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...    engine-size  \
# 1  convertible          rwd           front        88.6  ...            130
# 2    hatchback          rwd           front        94.5  ...            152
# 3        sedan          fwd           front        99.8  ...            109
# 4        sedan          4wd           front        99.4  ...            136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 1         mpfi  3.47    2.68               9.0        111      5000       21
# ...

# %%
ap.ix[1:5]
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
# 5          2                 ?         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...    engine-size  \
# 1  convertible          rwd           front        88.6  ...            130
# 2    hatchback          rwd           front        94.5  ...            152
# 3        sedan          fwd           front        99.8  ...            109
# 4        sedan          4wd           front        99.4  ...            136
# 5        sedan          fwd           front        99.8  ...            136
#
# ...

# %%
ap.iloc[1:5]['aspiration']
# Out:
# 1    std
# 2    std
# 3    std
# 4    std
# Name: aspiration, dtype: object

# %%
ap.ix[1:5]['aspiration']
# printa i 5-i red!
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#   """Entry point for launching an IPython kernel.
# 1    std
# 2    std
# 3    std
# 4    std
# 5    std
# Name: aspiration, dtype: object
