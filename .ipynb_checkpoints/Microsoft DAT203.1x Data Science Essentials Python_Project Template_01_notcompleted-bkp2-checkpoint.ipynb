# %% [markdown]
# ### Microsoft DAT203.1x Data Science Essentials Python_Project Template_version01_notcompleted ###
#
# The purpose of this notebook is to add value to the course primarily by enabling students to start faster with Data Science projects, gain experience and build a portfolio.
#
# After awesome lectures, some labs and assignments included in the course, I was missing more practical work, more assignments and more order and guidelines in the sea of available content from this field. Although course and curriculum is marketed as preparing for jobs in Data Science it is far from that. What is missing is experience. The most practical advice I found was to start yourself a project as soon as possible, i.e. to start to build a portfolio. But how? When? That is why I created this notebook(s) to boost and harness the course into gaining more experience.
#
# There are others paths to start projects and create portfolios (like Kaggle and Datacamp, just to name two). As well as there are other courses and specializations other than Microsoft Professional Program for Data Science. As stated, this notebook is intended primarily, but not limited, to get the most out of this course: Microsoft DAT203.1x Data Science Essentials, Python track.
#
# INSTRUCTIONS FOR USE: find few datasets from many available on the Internet. DO NOT use datasets from the course, because this is your project! Load, clean, transform, analyze and/or predict using this notebook. Start using as soon as possible, ideally immediately after viewing first video about coding in Python. Don't wait to complete all videos, labs and assignments to start a project in this notebook. Rather use it at the same time. The goal is when you complete videos, labs and assignments to have one or few completed Python projects in your portfolio. E.g. Analyzing and visualizing XYZ dataset, or Predicting (recommending ...) Y from ABC dataset.
#
# Add, modify, change, fail, debug and learn according to your needs.
#
# Future plans: to create notebooks for following courses from the Data Science track.
#
# Collaboration, debugging, development, teamwork and feedback are welcome.
#
# Credits: most of the Python commands are from the edX course Microsoft DAT203.1x Data Science Essentials
#
# Terms of use: the notebook is as it is. It is intended for students and alumni of the edX course Microsoft DAT203.1x Data Science Essentials and Microsoft Professional Program for Data Science. It is for learning, for noncommercial use. There is no warranty, no support and no maintenance.
#
# If you find this notebook useful, let everyone knows :) on edX forum, GitHub, LinkedIn etc.
#
# Domagoj Vukusic
# (Domagoj Vukušić)
# domagoj@vukusic.com.hr

# %% [markdown]
# ### From Module 1, video: 06 Using Code in Azure ML MSXDT2032016-V009700_DTH and 07 Using Python in Jupyter Notebooks ###

# %%
# Credit-Scoring-Clean.csv is a file from the course. Keep it in the same directory as this notebook.
# Replace Credit-Scoring-Clean.csv with a file/dataset of your choice for your project.
# Import file/dataset
# YOUR CODE HERE:
import pandas as pd
newdataframe = pd.read_csv('Credit-Scoring-Clean.csv')

# %%
newdataframe.dtypes   #names of dataframe columns and their types
# Out:
# CheckingAcctStat          object
# Duration                 float64
# CreditHistory             object
# Purpose                   object
# CreditAmount             float64
# Savings                   object
# Employment                object
# InstallmentRatePecnt     float64
# SexAndStatus              object
# OtherDetorsGuarantors     object
# PresentResidenceTime     float64
# Property                  object
# Age                      float64
# OtherInstalments          object
# Housing                   object
# ExistingCreditsAtBank    float64
# Job                       object
# NumberDependents         float64
# Telephone                 object
# ForeignWorker             object
# CreditStatus               int64
# dtype: object

# %%
# creditframe is Pandas dataframe.

# %% [markdown]
# ### Lab01

# %%
# from lab01
def azureml_main(creditframe):   # 1 dataframes as input to python script; can change func. name if you wish;
    drop_cols = ['SexAndStatus', 'OtherDetorsGuarantors']   #list of columns I want to remove
    creditframe.drop(drop_cols, axis = 1, inplace = True)
    return creditframe

# %%
azureml_main(newdataframe)
# Out:
#     CheckingAcctStat  Duration CreditHistory Purpose  CreditAmount Savings  \
# 0                A11  0.205882           A32     A43      0.161770     A61
# 1                A14  0.294118           A32     A43      0.058380     A62
# 2                A14  0.205882           A32     A43      0.069055     A61
# 3                A11  0.647059           A32     A43      0.358094     A61
# 4                A13  0.029412           A33     A43      0.023825     A61
# 5                A11  0.029412           A32     A43      0.131892     A63
# 6                A14  0.205882           A34     A46      0.088808     A62
# 7                A11  0.117647           A32     A48      0.035875     A61
# 8                A11  0.029412           A34     A40      0.022890     A64
# 9                A14  0.161765           A32     A42      0.108452     A63
# 10               A14  0.470588           A32     A40      0.036261     A63
# ...

# %%
newdataframe.dtypes   #names of dataframe columns and their types
# Out:
# CheckingAcctStat          object
# Duration                 float64
# CreditHistory             object
# Purpose                   object
# CreditAmount             float64
# Savings                   object
# Employment                object
# InstallmentRatePecnt     float64
# PresentResidenceTime     float64
# Property                  object
# Age                      float64
# OtherInstalments          object
# Housing                   object
# ExistingCreditsAtBank    float64
# Job                       object
# NumberDependents         float64
# Telephone                 object
# ForeignWorker             object
# CreditStatus               int64
# dtype: object

# %% [markdown]
# #### Module 2, video 19 Viewing Summary Statistics in Python MSXDT2032016-V011700_DTH ####

# %% [markdown]
# #### Load the data set ####

# %%
# from lab02
## Cell 1 (Auto-generated by Azure ML)
"""from azureml import Workspace

ws = Workspace()
ds = ws.datasets['Automobile price data (Raw)']
frame = ds.to_dataframe()"""

frame = pd.read_csv('Automobile price data _Raw_.csv')
# the file is downloaded from https://studio.azureml.net/ to the same folder where this notebook is stored, on C: drive.


## Cell 2 (Auto-generated by Azure ML)
frame
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# 5            2                 ?         audi       gas        std
# 6            1               158         audi       gas        std
# 7            1                 ?         audi       gas        std
# 8            1               158         audi       gas      turbo
# 9            0                 ?         audi       gas      turbo
# 10           2               192          bmw       gas        std
# 11           0               192          bmw       gas        std
# 12           0               188          bmw       gas        std
# ...

# %%
frame.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...    engine-size  \
# 0  convertible          rwd           front        88.6  ...            130
# 1  convertible          rwd           front        88.6  ...            130
# 2    hatchback          rwd           front        94.5  ...            152
# 3        sedan          fwd           front        99.8  ...            109
# 4        sedan          4wd           front        99.4  ...            136
#
# ...

# %%
## Cell 3
# import pandas as pd
import numpy as np
cols = ['price', 'bore', 'stroke', 'horsepower', 'peak-rpm']
## Convert the '?' to a nan
for column in cols:
        frame.loc[frame[column] == '?', column] = np.nan
## Coerce colums to numeric
for col in cols:
    frame[col] = pd.to_numeric(frame[col])
## Drop rows with missing values    
frame.dropna(axis = 0, inplace = True)
print('dimensions = ' + str(frame.shape)) # print dimensions of the data frame
print(frame.dtypes) # print the data types of the columns
# Out:
# dimensions = (195, 26)
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %%
## Cell 4
def describe(df, col):
    ## Compute the summary stats
    desc = df[col].describe()
    
    ## Change the name of the 50% index to median
    idx = desc.index.tolist()
    idx[5] = 'median'
    desc.index = idx
    return desc

# %%
## Cell 5
describe(frame, 'price')
describe(frame, 'horsepower')
# Out:
# count     195.000000
# mean      103.271795
# std        37.869730
# min        48.000000
# 25%        70.000000
# median     95.000000
# 75%       116.000000
# max       262.000000
# Name: horsepower, dtype: float64

# %%
## Cell 6
def plotstats(df, col):
    import matplotlib.pyplot as plt
    ## Setup for ploting two charts one over the other
    fig, ax = plt.subplots(2, 1, figsize = (12,8))
    
    ## First a box plot
    df.dropna().boxplot(col, ax = ax[0], vert=False,
                        return_type='dict')
    ## Plot the histogram   
    temp = df[col].as_matrix()
    ax[1].hist(temp, bins = 30, alpha = 0.7)
    plt.xlabel(col)
    return [col]

# %%
## Cell 7
# %matplotlib inline
plotstats(frame, 'price')
# Out:
# ['price']

# %% [markdown]
# #### 22 Viewing Correlation in Python MSXDT2032016-V011500_DTH.mp4 ####

# %%
def auto_corr(df, colm):
    import matplotlib.pyplot as plt
    import pandas as pd

    # create a scatterplot of the feature vs. price
    fig = plt.figure(1, figsize=(9, 9))
    ax = fig.gca()
    df.plot(kind = 'scatter', x = 'price', y = colm, ax = ax)
    
    # compute the correlation and covariance and return the
    # values as pandas series
    corr = df[['price', colm]].corr(method='pearson').as_matrix()[0][1]
    cov = df[['price', colm]].cov().as_matrix()[0][1]
    return pd.Series([corr, cov], index = ['Correlation', 'Covariance'])
auto_corr(frame, 'engine-size')
# Out:
# Correlation         0.888942
# Covariance     296733.640127
# dtype: float64

# %%
auto_corr(frame, 'city-mpg')
# Out:
# Correlation       -0.702685
# Covariance    -36238.614036
# dtype: float64

# %%
## Cell 7
# %matplotlib inline
plotstats(frame, 'horsepower')
# Out:
# ['horsepower']

# %% [markdown]
# ### Module3 Lab01/2 Simulation

# %%
# Create a Function to Plot Distributions
# %matplotlib inline
def dist_summary(dist, names = 'dist_name'):
    import pandas as pd
    import matplotlib.pyplot as plt
    ser = pd.Series(dist)
    fig = plt.figure(1, figsize=(9, 6))
    ax = fig.gca()
    ser.hist(ax = ax, bins = 120)
    ax.set_title('Frequency distribution of ' + names)
    ax.set_ylabel('Frequency')
    plt.show()
    return(ser.describe())

# %%
# Simulate Customers Using a Normal Distribution
def sim_normal(nums, mean = 600, sd = 30):
    import numpy as np
    import numpy.random as nr
    for n in nums:
        dist = nr.normal(loc = mean, scale = sd, size = n)
        titl = 'Normal distribution with ' + str(n) + ' values'
        print('Summary for ' + str(n) + ' samples')
        print(dist_summary(dist, titl))   
        print('Emperical 95% CIs')
        print(np.percentile(dist, [2.5, 97.5]))
        print(' ')
    return('Done!')

# %%
nums = [100, 1000, 10000, 100000]
sim_normal(nums)
# Out:
# Summary for 100 samples
# count    100.000000
# mean     600.778466
# std       28.542444
# min      542.038912
# 25%      581.784348
# 50%      597.608673
# 75%      621.200446
# max      674.317081
# dtype: float64
# Emperical 95% CIs
# [ 547.25628983  655.67761461]
#
# Summary for 1000 samples
# count    1000.000000
# mean      600.931901
# std        29.204254
# min       510.509239
# 25%       581.397421
# 50%       599.901477
# 75%       620.964502
# max       712.674458
# dtype: float64
# Emperical 95% CIs
# [ 545.08324682  657.41073871]
#
# Summary for 10000 samples
# count    10000.000000
# mean       600.167774
# std         30.078127
# min        480.149409
# 25%        579.751543
# 50%        600.289545
# 75%        620.875725
# max        723.133432
# dtype: float64
# Emperical 95% CIs
# [ 541.52453982  659.22909987]
#
# Summary for 100000 samples
# count    100000.000000
# mean        600.057552
# std          29.988681
# min         474.872825
# 25%         579.875322
# ...

# %%
# Simulate Customers Using a Poisson Distribution
def sim_poisson(nums, mean = 600):
    import numpy as np
    import numpy.random as nr
    for n in nums:
        dist = nr.poisson(lam = mean, size = n)
        titl = 'Poisson distribution with ' + str(n) + ' values'
        print(dist_summary(dist, titl))    
        print('Emperical 95% CIs')
        print(np.percentile(dist, [2.5, 97.5]))
        print(' ')
    return('Done!')

# %%
sim_poisson([100000])
# Out:
# count    100000.000000
# mean        599.959510
# std          24.457408
# min         496.000000
# 25%         583.000000
# 50%         600.000000
# 75%         616.000000
# max         726.000000
# dtype: float64
# Emperical 95% CIs
# [ 553.  648.]
# 'Done!'

# %%
# Exercise 2: Computing Specialized Random Variables

# Compute a Distribution for Profits
def gen_profits(num):  
    import numpy.random as nr
    unif = nr.uniform(size = num)
    out = [5 if x < 0.3 else (3.5 if x < 0.6 else 4) for x in unif]
    return(out)

# %%
prfts = gen_profits(100000)
dist_summary(prfts, 'profits')
# Out:
# count    100000.000000
# mean          4.150740
# std           0.594181
# min           3.500000
# 25%           3.500000
# 50%           4.000000
# 75%           5.000000
# max           5.000000
# dtype: float64

# %%
# Compute a Distribution for Tips
def gen_tips(num):  
    import numpy.random as nr
    unif = nr.uniform(size = num)
    out = [0 if x < 0.5 else (0.25 if x < 0.7 
      else (1.0 if x < 0.9 else 2.0)) for x in unif]
    return(out)

# %%
tps = gen_tips(100000)
dist_summary(tps, 'tips')
# Out:
# count    100000.000000
# mean          0.448813
# std           0.639003
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           1.000000
# max           2.000000
# dtype: float64

# %%
# Exercise 3: Simulating Lemonade Stand Income

# Create a Function to Simulate Lemonade Stand Income
def sim_lemonade(num, mean = 1200, sd = 40, pois = False):
    ## Simulate the profits and tips for
    ## a lemonade stand.
    import numpy.random as nr
  
    ## number of customer arrivals
    if pois:
        arrivals = nr.poisson(lam = mean, size = num)
    else:
        arrivals = nr.normal(loc = mean, scale = sd, size = num) 

    print(dist_summary(arrivals, 'customer arrivals per day'))
  
    ## Compute distibution of average profit per arrival
    proft = gen_profits(num)
    print(dist_summary(proft, 'profit per arrival'))
  
    ## Total profits are profit per arrival 
    ## times number of arrivals.
    total_profit = arrivals * proft 
    print(dist_summary(total_profit, 'total profit per day'))
  
    ## Compute distribution of average tips per arrival
    tps = gen_tips(num)
    print(dist_summary(tps, 'tips per arrival'))
  
    ## Compute average tips per day
    total_tips = arrivals * tps
    print(dist_summary(total_tips, 'total tips per day'))
  
    ## Compute total profits plus total tips.
    total_take = total_profit + total_tips 
    return(dist_summary(total_take, 'total net per day'))

# %%
# Run the code below to run the simulation for 100,000 values, using the default mean and standard deviation
sim_lemonade(100000)
# Out:
# count    100000.000000
# mean       1200.070322
# std          39.917624
# min        1027.834952
# 25%        1172.937335
# 50%        1200.012622
# 75%        1226.980245
# max        1369.963047
# dtype: float64
# count    100000.000000
# mean          4.154190
# std           0.595201
# min           3.500000
# 25%           3.500000
# 50%           4.000000
# 75%           5.000000
# max           5.000000
# dtype: float64
# count    100000.000000
# mean       4985.427208
# std         734.465860
# min        3640.139234
# 25%        4335.510006
# 50%        4801.825287
# 75%        5813.718917
# max        6806.650656
# dtype: float64
# count    100000.000000
# mean          0.450870
# std           0.641822
# min           0.000000
# 25%           0.000000
# 50%           0.125000
# 75%           1.000000
# max           2.000000
# dtype: float64
# count    100000.000000
# mean        541.124687
# std         770.992176
# min           0.000000
# 25%           0.000000
# ...

# %%
# Re-run the simulation of the lemonade stand for 100,000 values with the expected number of customer arrivals per day 
# increased to 1200 and a standard deviation of 40
sim_lemonade(100000, mean = 1200, sd = 40, pois = False)
# Out:
# count    100000.000000
# mean       1199.966065
# std          39.994691
# min        1027.042156
# 25%        1172.884115
# 50%        1199.984651
# 75%        1227.092249
# max        1376.064446
# dtype: float64
# count    100000.000000
# mean          4.149150
# std           0.594582
# min           3.500000
# 25%           3.500000
# 50%           4.000000
# 75%           5.000000
# max           5.000000
# dtype: float64
# count    100000.000000
# mean       4978.822407
# std         732.756485
# min        3658.099018
# 25%        4330.898664
# 50%        4799.353111
# 75%        5808.037715
# max        6782.066807
# dtype: float64
# count    100000.000000
# mean          0.451965
# std           0.641450
# min           0.000000
# 25%           0.000000
# 50%           0.250000
# 75%           1.000000
# max           2.000000
# dtype: float64
# count    100000.000000
# mean        542.342228
# std         770.422172
# min           0.000000
# 25%           0.000000
# ...

# %% [markdown]
# ### Module3 Lab02/2 Hypothesis Testing
# #### Load and examine the data set

# %%
# already imported: import pandas as pd
newdataframe = pd.read_csv('GaltonFamilies.csv')

# %%
newdataframe.head()
# Out:
#    Case family  father  mother  midparentHeight  children  childNum  gender  \
# 0     1      1    78.5    67.0            75.43         4         1    male
# 1     2      1    78.5    67.0            75.43         4         2  female
# 2     3      1    78.5    67.0            75.43         4         3  female
# 3     4      1    78.5    67.0            75.43         4         4  female
# 4     5      2    75.5    66.5            73.66         4         1    male
#
#    childHeight
# 0         73.2
# 1         69.2
# 2         69.0
# 3         69.0
# 4         73.5

# %%
newdataframe.shape
# Out:
# (934, 9)

# %% [markdown]
# #### Visualizing some relationships in these data

# %%
# %matplotlib inline
def hist_family(df, col1, col2, num_bins = 30):
    import matplotlib.pyplot as plt
    ## Setup for ploting two charts one over the other
    fig, ax = plt.subplots(2, 1, figsize = (12,8))
    
    mins = min([df[col1].min(), df[col2].min()])
    maxs = max([df[col1].max(), df[col2].max()])
    
    mean1 = df[col1].mean()
    mean2 = df[col2].mean()
    
    ## Plot the histogram   
    temp = df[col1].as_matrix()
    ax[1].hist(temp, bins = 30, alpha = 0.7)
    ax[1].set_xlim([mins, maxs])
    ax[1].axvline(x=mean1, color = 'red', linewidth = 4)
    ax[1].set_ylabel('Count')
    ax[1].set_xlabel(col1)
    
    ## Plot the histogram   
    temp = df[col2].as_matrix()
    ax[0].hist(temp, bins = 30, alpha = 0.7)
    ax[0].set_xlim([mins, maxs])
    ax[0].axvline(x=mean2, color = 'red', linewidth = 4)
    ax[0].set_ylabel('Count')
    ax[0].set_xlabel(col2)
    
    return [col1, col2]
sons = newdataframe[newdataframe.gender == 'male']
hist_family(sons, 'childHeight', 'mother')
# Out:
# ['childHeight', 'mother']

# %%
daughters = newdataframe[newdataframe.gender == 'female']
hist_family(daughters, 'childHeight', 'mother')
# Out:
# ['childHeight', 'mother']

# %% [markdown]
# #### Apply t test

# %%
def family_test(df, col1, col2, alpha):
    from scipy import stats
    import scipy.stats as ss
    import pandas as pd
    import statsmodels.stats.weightstats as ws
    
    n, _, diff, var, _, _ = stats.describe(df[col1] - df[col2])
    degfree = n - 1

    temp1 = df[col1].as_matrix()
    temp2 = df[col2].as_matrix()
    res = ss.ttest_rel(temp1, temp2)
      
    means = ws.CompareMeans(ws.DescrStatsW(temp1), ws.DescrStatsW(temp2))
    confint = means.tconfint_diff(alpha=alpha, alternative='two-sided', usevar='unequal') 
    degfree = means.dof_satt()

    index = ['DegFreedom', 'Difference', 'Statistic', 'PValue', 'Low95CI', 'High95CI']
    return pd.Series([degfree, diff, res[0], res[1], confint[0], confint[1]], index = index)   
    
def hist_family_conf(df, col1, col2, num_bins = 30, alpha =0.05):
    import matplotlib.pyplot as plt
    ## Setup for ploting two charts one over the other
    fig, ax = plt.subplots(2, 1, figsize = (12,8))
    
    mins = min([df[col1].min(), df[col2].min()])
    maxs = max([df[col1].max(), df[col2].max()])
    
    mean1 = df[col1].mean()
    mean2 = df[col2].mean()
    
    tStat = family_test(df, col1, col2, alpha)
    pv1 = mean2 + tStat[4]    
    pv2 = mean2 + tStat[5]
    
    ## Plot the histogram   
    temp = df[col1].as_matrix()
    ax[1].hist(temp, bins = 30, alpha = 0.7)
    ax[1].set_xlim([mins, maxs])
    ax[1].axvline(x=mean1, color = 'red', linewidth = 4)    
    ax[1].axvline(x=pv1, color = 'red', linestyle='--', linewidth = 4)
    ax[1].axvline(x=pv2, color = 'red', linestyle='--', linewidth = 4)
    ax[1].set_ylabel('Count')
    ax[1].set_xlabel(col1)
    
    ## Plot the histogram   
    temp = df[col2].as_matrix()
    ax[0].hist(temp, bins = 30, alpha = 0.7)
    ax[0].set_xlim([mins, maxs])
    ax[0].axvline(x=mean2, color = 'red', linewidth = 4)
    ax[0].set_ylabel('Count')
    ax[0].set_xlabel(col2)
    
    return tStat

hist_family_conf(sons, 'mother', 'childHeight')
# Out:
# DegFreedom     9.459687e+02
# Difference    -5.200832e+00
# Statistic     -3.949802e+01
# PValue        6.323181e-153
# Low95CI       -5.514333e+00
# High95CI      -4.887331e+00
# dtype: float64

# %%
hist_family_conf(daughters, 'mother', 'childHeight')
# Out:
# DegFreedom    902.412325
# Difference      0.044812
# Statistic       0.350524
# PValue          0.726109
# Low95CI        -0.256132
# High95CI        0.345756
# dtype: float64

# %% [markdown]
# #### Evaluation question
#
# You have found that you could not reject the null hypothesis that there was no significant difference between the heights of mothers and their adult dauhters. But what about the difference in height between fathers and their adult daughters? Perform the t-test on the Galton data set to answer the question below:
#
#     Can you reject the null hypothesis that there is no significant difference in the heights of fathers and their adult daughters.

# %%
hist_family_conf(sons, 'mother', 'childHeight')
# Out:
# DegFreedom     9.459687e+02
# Difference    -5.200832e+00
# Statistic     -3.949802e+01
# PValue        6.323181e-153
# Low95CI       -5.514333e+00
# High95CI      -4.887331e+00
# dtype: float64

# %%
hist_family_conf(daughters, 'father', 'childHeight')
# Out:
# DegFreedom     8.919930e+02
# Difference     5.156291e+00
# Statistic      4.086498e+01
# PValue        7.001247e-154
# Low95CI        4.829558e+00
# High95CI       5.483025e+00
# dtype: float64

# %% [markdown]
# Examine the printed table of results and the charts noting the following:
#
#     The difference of the means is 5.15 inches. You can see this difference graphically by comparing the positions of the solid red lines showing the means of the two distirbutions.
#     The critical value of the two-sided t-statistic at 891 degrees of freedom is 1.96?. The t-statistic ("Statistic") of 40.86 is larger than this critical value.
#     The P-value is effectively 0, which is smaller than the confidence level of 0.05.
#     The 95% confidence interval of the difference in means is from 5.5 to 4.8, which does not overlap 0. You can see the confidence interval plotted as the two dashed red lines in the lower chart shown above. This confidence interval around the mean of the father(mother)'s heights does not overlap with the mean of the son's height.
#
# Overall, these statistics indicate you can reject the null hypothesis, or that there difference in the means is not 0.

# %% [markdown]
# ### Module4
# #### Video 34 Getting started with Pandas, 35 Pandas Data frame working with

# %% [markdown]
# #### Load the Data Set

# %%
"""from azureml import Workspace

ws = Workspace()
ds = ws.datasets['Automobile price data (Raw)']
auto_prices = ds.to_dataframe()"""
import pandas as pd

auto_prices = pd.read_csv('Automobile price data _Raw_.csv')
# the file is downloaded from https://studio.azureml.net/ to the same folder where this notebook is stored, on C: drive.


def clean_auto_data(auto_prices):
    'Function to load the auto price data set from a .csv file' 
    import pandas as pd
    import numpy as np
    
    ## Remove rows with missing values, accounting for mising values coded as '?'
    cols = ['price', 'bore', 'stroke', 
          'horsepower', 'peak-rpm']
    for column in cols:
        auto_prices.loc[auto_prices[column] == '?', column] = np.nan
    auto_prices.dropna(axis = 0, inplace = True)

    ## Convert some columns to numeric values
    for column in cols:
        auto_prices[column] = pd.to_numeric(auto_prices[column])
        
    return auto_prices
auto_prices = clean_auto_data(auto_prices)

# %% [markdown]
# #### Explore the data frame

# %%
auto_prices.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
auto_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 195 entries, 0 to 204
# Data columns (total 26 columns):
# symboling            195 non-null int64
# normalized-losses    195 non-null object
# make                 195 non-null object
# fuel-type            195 non-null object
# aspiration           195 non-null object
# num-of-doors         195 non-null object
# body-style           195 non-null object
# drive-wheels         195 non-null object
# engine-location      195 non-null object
# wheel-base           195 non-null float64
# length               195 non-null float64
# width                195 non-null float64
# height               195 non-null float64
# curb-weight          195 non-null int64
# engine-type          195 non-null object
# num-of-cylinders     195 non-null object
# engine-size          195 non-null int64
# fuel-system          195 non-null object
# bore                 195 non-null float64
# stroke               195 non-null float64
# ...

# %%
auto_prices.shape
# Out:
# (195, 26)

# %% [markdown]
# #### Filter a Data Frame

# %%
df = auto_prices[auto_prices.make == 'audi']
print(df)
# Out:
#    symboling normalized-losses  make fuel-type aspiration num-of-doors  \
# 3          2               164  audi       gas        std         four
# 4          2               164  audi       gas        std         four
# 5          2                 ?  audi       gas        std          two
# 6          1               158  audi       gas        std         four
# 7          1                 ?  audi       gas        std         four
# 8          1               158  audi       gas      turbo         four
#
#   body-style drive-wheels engine-location  wheel-base  ...    engine-size  \
# 3      sedan          fwd           front        99.8  ...            109
# 4      sedan          4wd           front        99.4  ...            136
# 5      sedan          fwd           front        99.8  ...            136
# 6      sedan          fwd           front       105.8  ...            136
# 7      wagon          fwd           front       105.8  ...            136
# ...

# %% [markdown]
# ### Basic Data Frame Operations
#
# #### Some basic operations for manipulation of data frame.
#
# #### Take slices

# %%
auto_prices[:4]
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...    engine-size  \
# 0  convertible          rwd           front        88.6  ...            130
# 1  convertible          rwd           front        88.6  ...            130
# 2    hatchback          rwd           front        94.5  ...            152
# 3        sedan          fwd           front        99.8  ...            109
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# ...

# %%
df_slice = auto_prices[9:14]
df_slice
# Out:
#     symboling normalized-losses make fuel-type aspiration num-of-doors  \
# 10          2               192  bmw       gas        std          two
# 11          0               192  bmw       gas        std         four
# 12          0               188  bmw       gas        std          two
# 13          0               188  bmw       gas        std         four
# 14          1                 ?  bmw       gas        std         four
#
#    body-style drive-wheels engine-location  wheel-base  ...    engine-size  \
# 10      sedan          rwd           front       101.2  ...            108
# 11      sedan          rwd           front       101.2  ...            108
# 12      sedan          rwd           front       101.2  ...            164
# 13      sedan          rwd           front       101.2  ...            164
# 14      sedan          rwd           front       103.5  ...            164
#
#     fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# ...

# %%
auto_prices.iloc[9:14]
# Out:
#     symboling normalized-losses make fuel-type aspiration num-of-doors  \
# 10          2               192  bmw       gas        std          two
# 11          0               192  bmw       gas        std         four
# 12          0               188  bmw       gas        std          two
# 13          0               188  bmw       gas        std         four
# 14          1                 ?  bmw       gas        std         four
#
#    body-style drive-wheels engine-location  wheel-base  ...    engine-size  \
# 10      sedan          rwd           front       101.2  ...            108
# 11      sedan          rwd           front       101.2  ...            108
# 12      sedan          rwd           front       101.2  ...            164
# 13      sedan          rwd           front       101.2  ...            164
# 14      sedan          rwd           front       103.5  ...            164
#
#     fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# ...

# %%
# extract every 10th row.
auto_prices[9::10]
# Out:
#      symboling normalized-losses        make fuel-type aspiration  \
# 10           2               192         bmw       gas        std
# 20           0                81   chevrolet       gas        std
# 30           2               137       honda       gas        std
# 40           0                85       honda       gas        std
# 52           1               104       mazda       gas        std
# 66           0                 ?       mazda    diesel        std
# 76           2               161  mitsubishi       gas        std
# 86           1               125  mitsubishi       gas        std
# 96           1               122      nissan       gas        std
# 106          1               231      nissan       gas        std
# 116          0               161      peugot    diesel      turbo
# 126          3                 ?     porsche       gas        std
# 139          2                83      subaru       gas        std
# ...

# %% [markdown]
# #### loc, iloc and ix
# #### Random sample a data frame

# %%
# randomly sample 5% of the rows in the data frame
df_rand = auto_prices.sample(frac = 0.05)
df_rand
# Out:
#      symboling normalized-losses           make fuel-type aspiration  \
# 169          2               134         toyota       gas        std
# 119          1               119       plymouth       gas      turbo
# 16           0                 ?            bmw       gas        std
# 68          -1                93  mercedes-benz    diesel      turbo
# 66           0                 ?          mazda    diesel        std
# 196         -2               103          volvo       gas        std
# 165          1               168         toyota       gas        std
# 10           2               192            bmw       gas        std
# 198         -2               103          volvo       gas      turbo
# 79           1               161     mitsubishi       gas      turbo
#
#     num-of-doors body-style drive-wheels engine-location  wheel-base  ...    \
# 169          two  hatchback          rwd           front        98.4  ...
# ...

# %% [markdown]
# #### Select columns from dataframe

# %%
df['price']   # df comes with 6 rows only.
# Out:
# 3    13950
# 4    17450
# 5    15250
# 6    17710
# 7    18920
# 8    23875
# Name: price, dtype: int64

# %%
df_2 = df[['drive-wheels', 'wheel-base', 'curb-weight', 'horsepower', 'price']]
df_2
# Out:
#   drive-wheels  wheel-base  curb-weight  horsepower  price
# 3          fwd        99.8         2337         102  13950
# 4          4wd        99.4         2824         115  17450
# 5          fwd        99.8         2507         110  15250
# 6          fwd       105.8         2844         110  17710
# 7          fwd       105.8         2954         110  18920
# 8          fwd       105.8         3086         140  23875

# %%
df.loc[:, ['drive-wheels', 'wheel-base', 'curb-weight', 'horsepower', 'price']]
# Out:
#   drive-wheels  wheel-base  curb-weight  horsepower  price
# 3          fwd        99.8         2337         102  13950
# 4          4wd        99.4         2824         115  17450
# 5          fwd        99.8         2507         110  15250
# 6          fwd       105.8         2844         110  17710
# 7          fwd       105.8         2954         110  18920
# 8          fwd       105.8         3086         140  23875

# %%
df_drop = df.drop(['symboling', 'normalized-losses', 'engine-size'], axis = 1)
df_drop
# Out:
#    make fuel-type aspiration num-of-doors body-style drive-wheels  \
# 3  audi       gas        std         four      sedan          fwd
# 4  audi       gas        std         four      sedan          4wd
# 5  audi       gas        std          two      sedan          fwd
# 6  audi       gas        std         four      sedan          fwd
# 7  audi       gas        std         four      wagon          fwd
# 8  audi       gas      turbo         four      sedan          fwd
#
#   engine-location  wheel-base  length  width  ...    num-of-cylinders  \
# 3           front        99.8   176.6   66.2  ...                four
# 4           front        99.4   176.6   66.4  ...                five
# 5           front        99.8   177.3   66.3  ...                five
# 6           front       105.8   192.7   71.4  ...                five
# 7           front       105.8   192.7   71.4  ...                five
# 8           front       105.8   192.7   71.4  ...                five
#
# ...

# %%
# se the Pandas iloc method to select the first 5 columns of the df data frame.
df_first5 = df.iloc[:, 0:5]
df_first5
# Out:
#    symboling normalized-losses  make fuel-type aspiration
# 3          2               164  audi       gas        std
# 4          2               164  audi       gas        std
# 5          2                 ?  audi       gas        std
# 6          1               158  audi       gas        std
# 7          1                 ?  audi       gas        std
# 8          1               158  audi       gas      turbo

# %% [markdown]
# #### Sort a data frame

# %%
df_sort = df_2.sort_values(by = ['drive-wheels', 'price'], axis = 0)
df_sort
# Out:
#   drive-wheels  wheel-base  curb-weight  horsepower  price
# 4          4wd        99.4         2824         115  17450
# 3          fwd        99.8         2337         102  13950
# 5          fwd        99.8         2507         110  15250
# 6          fwd       105.8         2844         110  17710
# 7          fwd       105.8         2954         110  18920
# 8          fwd       105.8         3086         140  23875

# %%
# sort the df_2 data frame in decending order, first by drive wheels and then by housepower. 
# Hint, use the ascending=False argument.
df_sort = df_2.sort_values(by = ['drive-wheels', 'horsepower'], axis = 0, ascending=False)
df_sort
# Out:
#   drive-wheels  wheel-base  curb-weight  horsepower  price
# 8          fwd       105.8         3086         140  23875
# 5          fwd        99.8         2507         110  15250
# 6          fwd       105.8         2844         110  17710
# 7          fwd       105.8         2954         110  18920
# 3          fwd        99.8         2337         102  13950
# 4          4wd        99.4         2824         115  17450

# %% [markdown]
# ## Computing on Data Frames
#
# ### Compute new columns

# %%
df_2.loc[:, 'curb-weight-kg'] = df_2['curb-weight'].divide(2.205)
df_2
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:337: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#   drive-wheels  wheel-base  curb-weight  horsepower  price  curb-weight-kg
# 3          fwd        99.8         2337         102  13950     1059.863946
# ...

# %% [markdown]
# ### The apply, applymap and map methods

# %%
import math
cols = ['wheel-base', 'curb-weight', 'horsepower', 'price', 'curb-weight-kg']
df_2.loc[:, cols] = df_2[cols].applymap(lambda x: math.log(x))
df_2
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#   drive-wheels  wheel-base  curb-weight  horsepower      price  curb-weight-kg
# 3          fwd    4.603168     7.756623    4.624973   9.543235        6.965896
# 4          4wd    4.599152     7.945910    4.744932   9.767095        7.155182
# 5          fwd    4.603168     7.826842    4.700480   9.632335        7.036115
# 6          fwd    4.661551     7.952967    4.700480   9.781885        7.162239
# 7          fwd    4.661551     7.990915    4.700480   9.847975        7.200188
# 8          fwd    4.661551     8.034631    4.941642  10.080587        7.243904

# %%
# aggregated result
# CAUTION, DOUBLE [[]]
auto_prices[['wheel-base', 'curb-weight', 'horsepower', 'price']].apply(lambda x : sum(x))
# Out:
# wheel-base       19284.8
# curb-weight     499005.0
# horsepower       20138.0
# price          2583363.0
# dtype: float64

# %%
#  The code in the cell below selects a single column from the data frame (to DataSeries), 
# computes the natural log of the values and prints the fist 10 values (a missing value is skipped). 
import math
log_price = auto_prices['price'].map(lambda x : math.log(x))
log_price[:10]
# Out:
# 0      9.510075
# 1      9.711116
# 2      9.711116
# 3      9.543235
# 4      9.767095
# 5      9.632335
# 6      9.781885
# 7      9.847975
# 8     10.080587
# 10     9.706864
# Name: price, dtype: float64

# %%
# YOU: create and execute code to compute the variance of the wheel base and curb weight columns using the `numpy.var` method.
import numpy as np
cols = ['wheel-base', 'curb-weight']
auto_var = auto_prices[cols].apply(lambda x : np.var(x))
auto_var
# Out:
# wheel-base         37.409064
# curb-weight    273914.738462
# dtype: float64

# %%
# YOU: create and execute code to compute the variance of the wheel base and curb weight columns using the `numpy.var` method.
import numpy as np
cols = ['wheel-base', 'curb-weight']
auto_var2 = auto_prices[cols].var()
auto_var2
# Out:
# wheel-base         37.601894
# curb-weight    275326.670103
# dtype: float64

# %%
# YOU: 
auto_prices['wheel-base'].var()
# Out:
# 37.6018942638118

# %%
# YOU: 
auto_prices['curb-weight'].var()
# Out:
# 275326.6701030928

# %%
auto_prices['wheel-base'].describe()
# Out:
# count    195.000000
# mean      98.896410
# std        6.132038
# min       86.600000
# 25%       94.500000
# 50%       97.000000
# 75%      102.400000
# max      120.900000
# Name: wheel-base, dtype: float64

# %% [markdown]
# ## Chaining Pandas methods

# %%
auto_prices.loc[auto_prices.make == 'audi', ['wheel-base', 'curb-weight', 'horsepower', 'price']].applymap(lambda x: math.log(x)).sort_values(by = 'price', axis = 0)
# Out:
#    wheel-base  curb-weight  horsepower      price
# 3    4.603168     7.756623    4.624973   9.543235
# 5    4.603168     7.826842    4.700480   9.632335
# 4    4.599152     7.945910    4.744932   9.767095
# 6    4.661551     7.952967    4.700480   9.781885
# 7    4.661551     7.990915    4.700480   9.847975
# 8    4.661551     8.034631    4.941642  10.080587

# %% [markdown]
# ### Using groupby in Pandas chains

# %%
auto_prices[['body-style', 'num-of-cylinders', 'price']].groupby(['body-style', 'num-of-cylinders']).count()
#3rd column is no. of cases. It is not a price :)
# Out:
#                               price
# body-style  num-of-cylinders
# convertible eight                 1
#             four                  4
#             six                   1
# hardtop     eight                 1
#             five                  1
#             four                  4
#             six                   2
# hatchback   four                 56
#             six                   6
#             three                 1
# sedan       eight                 2
#             five                  7
#             four                 71
#             six                  13
#             twelve                1
# wagon       five                  2
#             four                 20
#             six                   2

# %% [markdown]
# ### Aggregation with groupby

# %%
auto_prices.loc[:, ['body-style','curb-weight', 'price']].groupby(['body-style']).aggregate(np.mean).sort_values('price')
# Out:
#              curb-weight         price
# body-style
# hatchback    2315.063492   9763.984127
# wagon        2792.791667  12500.166667
# sedan        2625.893617  14459.755319
# convertible  2801.666667  21890.500000
# hardtop      2810.625000  22208.500000

# %%
# you: compute the mean of curb weight and price grouped by fuel type.
auto_prices.loc[:, ['fuel-type','curb-weight', 'price']].groupby(['fuel-type']).aggregate(np.mean)
#.sort_values('price')
# Out:
#            curb-weight     price
# fuel-type
# diesel     2898.800000  15838.15
# gas        2520.165714  12952.00

# %%
# you: compute the mean of curb weight and price grouped by fuel type.
auto_prices.loc[:, ['fuel-type','curb-weight', 'price']].groupby(['fuel-type']).aggregate(np.mean).sort_values('price')
# Out:
#            curb-weight     price
# fuel-type
# gas        2520.165714  12952.00
# diesel     2898.800000  15838.15

# %% [markdown]
# # Python Visualization for Exploration of Data
# ## Load and examine the data set

# %%
"""from azureml import Workspace

ws = Workspace()
ds = ws.datasets['Automobile price data (Raw)']
auto_prices = ds.to_dataframe()"""


auto_prices = pd.read_csv('Automobile price data _Raw_.csv')
# the file is downloaded from https://studio.azureml.net/ to the same folder where this notebook is stored, on C: drive.

def clean_auto_data(auto_prices):
    'Function to load the auto price data set from a .csv file' 
    import pandas as pd
    import numpy as np
    
    ## Remove rows with missing values, accounting for mising values coded as '?'
    cols = ['price', 'bore', 'stroke', 
          'horsepower', 'peak-rpm']
    for column in cols:
        auto_prices.loc[auto_prices[column] == '?', column] = np.nan
    auto_prices.dropna(axis = 0, inplace = True)

    ## Convert some columns to numeric values
    for column in cols:
        auto_prices[column] = pd.to_numeric(auto_prices[column])
        
    return auto_prices
auto_prices = clean_auto_data(auto_prices)

# %%
auto_prices.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...    engine-size  \
# 0  convertible          rwd           front        88.6  ...            130
# 1  convertible          rwd           front        88.6  ...            130
# 2    hatchback          rwd           front        94.5  ...            152
# 3        sedan          fwd           front        99.8  ...            109
# 4        sedan          4wd           front        99.4  ...            136
#
# ...

# %% [markdown]
# ### Bar plots

# %%
counts = auto_prices['make'].value_counts() # find the counts for each unique category
counts
# Out:
# toyota           32
# nissan           18
# mitsubishi       13
# honda            13
# mazda            13
# subaru           12
# volkswagen       12
# volvo            11
# peugot           11
# dodge             9
# mercedes-benz     8
# bmw               8
# plymouth          7
# saab              6
# audi              6
# porsche           4
# alfa-romero       3
# jaguar            3
# chevrolet         3
# isuzu             2
# mercury           1
# Name: make, dtype: int64

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,6)) # define plot area
ax = fig.gca() # define axis    
counts.plot.bar(ax = ax) # Use the plot.bar method on the counts data frame
ax.set_title('Number of auto types by make') # Give the plot a main title
ax.set_xlabel('Make') # Set text for the x axis
ax.set_ylabel('Number of autos')# Set text for y axis

# %%
fig = plt.figure(figsize=(8,6)) # define plot area
ax = fig.gca() # define axis    
auto_prices['engine-size'].plot.hist(ax = ax) # Use the plot.hist method on subset of the data frame
ax.set_title('Histogram of auto engine size') # Give the plot a main title
ax.set_xlabel('Engine size') # Set text for the x axis
ax.set_ylabel('Number of autos')# Set text for y axis

# %%
fig = plt.figure(figsize=(8,6)) # define plot area
ax = fig.gca() # define axis    
auto_prices[['engine-size','fuel-type']].boxplot(by = 'fuel-type', ax = ax) # Use the plot.bar method on the new data frame
ax.set_title('Box plots of auto engine size by fuel type') # Give the plot a main title
ax.set_xlabel('Fuel type') # Set text for the x axis
ax.set_ylabel('Engine size')# Set text for y axis

# %% [markdown]
# ### Kernel density plots and introduction to Seaborn
#
# video 40, combining matplotlib and seaborn gives more control on plotting, legend, labels...

# %%
"""creates a violin plot using the following recipe:
    Import the Seaborn package,
    Set a style for the plot grid.
    Define the kdeplot of the engine-size column."""

import seaborn as sns
sns.set_style("whitegrid")
sns.kdeplot(auto_prices['engine-size'])

# %%
"""specifing axes. The code in the cell below extends our simple recipe for Seaborn plots:
    Define a figure.
    Define one or more axes on the figure.
    Set a style for the plot grid.
    Define the kdeplot of the engine-size column.
    Use methods on the axes to control attributes like titles and axis labels.
"""
fig = plt.figure(figsize=(8,6)) # define plot area
ax = fig.gca() # define axis 
sns.set_style("whitegrid")
sns.kdeplot(auto_prices['engine-size'], ax = ax)
ax.set_title('KDE plot of auto engine size') # Give the plot a main title
ax.set_xlabel('Engine Size') # Set text for the x axis
ax.set_ylabel('Density')# Set text for y axis

# %% [markdown]
# ### Violin plots

# %%
fig = plt.figure(figsize=(8,6)) # define plot area
ax = fig.gca() # define axis 
sns.set_style("whitegrid")
sns.violinplot(x = 'fuel-type', y = 'engine-size', data = auto_prices, ax = ax)
ax.set_title('Violine plots of auto engine size by fule type') # Give the plot a main title
ax.set_xlabel('Fuel type') # Set text for the x axis
ax.set_ylabel('Engine size')# Set text for y axis

# %% [markdown]
# ### Scatter plots

# %%
# %matplotlib inline 
auto_prices.plot(kind = 'scatter', x = 'city-mpg', y = 'price')

# %%
"""improved recipe looks like this:

- Specify a figure, including a size.
- Define one or more axes within the figure.
- Use the pandas plot method of choice. Make sure you specify the axis you are using. 
- Use methods on the axes to control attributes like titles and axis labels. """

import matplotlib.pyplot as plt
fig = plt.figure(figsize=(6,6)) # define plot area
ax = fig.gca() # define axis                   
auto_prices.plot(kind = 'scatter', x = 'city-mpg', y = 'price', ax = ax)
ax.set_title('Scatter plot of price vs MPG') # Give the plot a main title
ax.set_xlabel('City MPG') # Set text for the x axis
ax.set_ylabel('Auto Price')# Set text for y axis

# %%
"""you: 
Create the following scatter plot:
    Plot engine-size against price.
    Set the figure size to 8 X 8.
    Provide a meaningful title, x-axis label, and y-axis label.
"""
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,8)) # define plot area
ax = fig.gca() # define axis                   
auto_prices.plot(kind = 'scatter', x = 'engine-size', y = 'price', ax = ax)
ax.set_title('Scatter plot of engine-size against price') # Give the plot a main title
ax.set_xlabel('Engine Size') # Set text for the x axis
ax.set_ylabel('Auto Price')# Set text for y axis

# %% [markdown]
# ### 2-D kernel density plots
# We can also create a two dimensional KDE plot. The code in the cell below creates a two dimensional kde plot of price and engine size(?, mpg) following the same recipe.

# %%
fig = plt.figure(figsize=(6,6)) # define plot area
ax = fig.gca() # define axis 
sns.set_style("whitegrid")
sns.kdeplot(auto_prices[['city-mpg', 'price']], ax = ax, cmap="Blues_d")
auto_prices.plot(kind = 'scatter', x = 'city-mpg', y = 'price', ax = ax)
ax.set_title('KDE plot of city mpg and price') # Give the plot a main title
ax.set_xlabel('city mpg') # Set text for the x axis
ax.set_ylabel('Price')# Set text for y axis

# %%
#DELETE this cell
"""fig = plt.figure(figsize=(8,6)) # define plot area
ax = fig.gca() # define axis 
sns.set_style("whitegrid")
sns.kdeplot(auto_prices['engine-size'], ax = ax)
ax.set_title('KDE plot of auto engine size') # Give the plot a main title
ax.set_xlabel('Engine Size') # Set text for the x axis
ax.set_ylabel('Density')# Set text for y axis
"""
fig = plt.figure(figsize=(6,6)) # define plot area
ax = fig.gca() # define axis 
sns.set_style("whitegrid")
sns.kdeplot(auto_prices[['engine-size', 'price']], ax = ax, cmap="Blues_d")
#sns.kdeplot(auto_prices[['price', 'engine-size']], ax = ax, cmap="Blues_d")
auto_prices.plot(kind = 'scatter', x = 'city-mpg', y = 'price', ax = ax)
ax.set_title('KDE plot of engine-size and price') # Give the plot a main title
ax.set_xlabel('Engine Size') # Set text for the x axis
ax.set_ylabel('Price')# Set text for y axis

# %% [markdown]
# ### Line plots

# %%
import pandas as pd
x = list(range(100))
y = [z * z for z in range(100)]
df = pd.DataFrame({'x':x, 'y':y})

# %%
fig = plt.figure(figsize=(6,6)) # define plot area
ax = fig.gca() # define axis                   
df.plot(x = 'x', y = 'y', ax = ax) ## line is the default plot type
ax.set_title('Line plot of x^2 vs. x') # Give the plot a main title
ax.set_xlabel('x') # Set text for the x axis
ax.set_ylabel('x^2')# Set text for y axis

# %% [markdown]
# ## Viewing multiple dimensions with aesthetics

# %%
sns.lmplot(x = 'city-mpg', y = 'price', data = auto_prices, hue = "fuel-type", palette="Set2", fit_reg = False)

# %%
"""The code in the function shown below divides the data into subsets and plots them with different aesthetics on the same set of axes. The recipe is:

    Import the required packages
    Loop over a list of column names for the horizontal axis. In this example we only specify one.
    Define a figure and axes for the plot
    Subset the data by gas and diesel cars.
    If the subset has more than zero members create scatter plots with the aesthetics defined. In this case, the attribute is color defined as either DarkBlue or Red.
    Create a list of patches and display the patches for the ledgend.
"""
def auto_color(df, plot_cols):
    import matplotlib.pyplot as plt
    import matplotlib.patches as mpatches
    for col in plot_cols:
        fig = plt.figure(figsize=(6,6))
        ax = fig.gca()
        temp1 = df.ix[df['fuel-type'] == 'gas']       
        temp2 = df.ix[df['fuel-type'] == 'diesel']
        if temp1.shape[0] > 0:                    
            temp1.plot(kind = 'scatter', x = col, y = 'price' , 
                           ax = ax, color = 'DarkBlue')                          
        if temp2.shape[0] > 0:                    
            temp2.plot(kind = 'scatter', x = col, y = 'price' , 
                           ax = ax, color = 'Red') 
    ax.set_title('Scatter plot of price vs. ' + col)
    red_patch = mpatches.Patch(color='Red', label='Diesel')   
    blue_patch = mpatches.Patch(color='DarkBlue', label='Gas')
    plt.legend(handles=[red_patch, blue_patch])
    return 'Done'
auto_color(auto_prices, ['city-mpg'])
# A similar effect can be achieved with Seaborn plots by choosing another color palette.
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#   app.launch_new_instance()
# 'Done'

# %% [markdown]
# ### Transparency

# %%
# With the transparency set to 0.3, you can now better see the density of autos 
# in areas of the plot with significant overplotting.
def auto_color(df, plot_cols):
    import matplotlib.pyplot as plt
    import matplotlib.patches as mpatches
    for col in plot_cols:
        fig = plt.figure(figsize=(6,6))
        ax = fig.gca()
        temp1 = df.ix[df['fuel-type'] == 'gas']       
        temp2 = df.ix[df['fuel-type'] == 'diesel']
        if temp1.shape[0] > 0:                    
            temp1.plot(kind = 'scatter', x = col, y = 'price' , 
                           ax = ax, color = 'DarkBlue', alpha = 0.3)                          
        if temp2.shape[0] > 0:                    
            temp2.plot(kind = 'scatter', x = col, y = 'price' , 
                           ax = ax, color = 'Red', alpha = 0.3) 
        ax.set_title('Scatter plot of price vs. ' + col)
        red_patch = mpatches.Patch(color='Red', label='Diesel')   
        blue_patch = mpatches.Patch(color='DarkBlue', label='Gas')
        plt.legend(handles=[red_patch, blue_patch])
    return plot_cols
auto_color(auto_prices, ['city-mpg'])
# Out:
# ['city-mpg']

# %%
"""YOU:
In this exercise you will create plots for some additional columns:
    Create a new code cell.
    Copy the code from the code cell above into the new cell.
    Change at least one of the color choices.
    Call the auto_color function with a list of different columns: ['engine-size', 'curb-weight'].
    Examine the resulting plots. What can you learn from these plots?
"""
def auto_color(df, plot_cols):
    import matplotlib.pyplot as plt
    import matplotlib.patches as mpatches
    for col in plot_cols:
        fig = plt.figure(figsize=(6,6))
        ax = fig.gca()
        temp1 = df.ix[df['fuel-type'] == 'gas']       
        temp2 = df.ix[df['fuel-type'] == 'diesel']
        if temp1.shape[0] > 0:                    
            temp1.plot(kind = 'scatter', x = col, y = 'price' , 
                           ax = ax, color = 'DarkBlue', alpha = 0.3)                          
        if temp2.shape[0] > 0:                    
            temp2.plot(kind = 'scatter', x = col, y = 'price' , 
                           ax = ax, color = 'Red', alpha = 0.3) 
        ax.set_title('Scatter plot of price vs. ' + col)
        red_patch = mpatches.Patch(color='Pink', label='Diesel')   
        blue_patch = mpatches.Patch(color='DarkBlue', label='Gas')
        plt.legend(handles=[red_patch, blue_patch])
    return plot_cols
auto_color(auto_prices, ['city-mpg'])
auto_color(auto_prices, ['engine-size'])
auto_color(auto_prices, ['curb-weight'])
# Out:
# ['curb-weight']

# %% [markdown]
# ### Using marker size

# %%
def auto_size(df, plot_cols):
    import matplotlib.pyplot as plt
    import matplotlib.patches as mpatches
    for col in plot_cols:
        fig = plt.figure(figsize=(6,6))
        ax = fig.gca()
        temp1 = df.ix[df['fuel-type'] == 'gas']       
        temp2 = df.ix[df['fuel-type'] == 'diesel']
        if temp1.shape[0] > 0:                    
            temp1.plot(kind = 'scatter', x = col, y = 'price' , 
                           ax = ax, color = 'DarkBlue', s= .5 * auto_prices['engine-size'], alpha = 0.3)                          
        if temp2.shape[0] > 0:                    
            temp2.plot(kind = 'scatter', x = col, y = 'price' , 
                           ax = ax, color = 'Red', s= .5 * auto_prices['engine-size'], alpha = 0.3) 
    ax.set_title('Scatter plot of price vs. ' + col + ' with engine size')
    red_patch = mpatches.Patch(color='Red', label='Diesel')   
    blue_patch = mpatches.Patch(color='DarkBlue', label='Gas')
    plt.legend(handles=[red_patch, blue_patch])
    return plot_cols
auto_size(auto_prices, ['city-mpg'])
# Out:
# ['city-mpg']

# %%
# The code in the cell below use the square of engine size to determine marker size.  

def auto_size_2(df, plot_cols):
    import matplotlib.pyplot as plt
    import matplotlib.patches as mpatches
    for col in plot_cols:
        fig = plt.figure(figsize=(6,6))
        ax = fig.gca()
        temp1 = df.ix[df['fuel-type'] == 'gas']       
        temp2 = df.ix[df['fuel-type'] == 'diesel']
        if temp1.shape[0] > 0:                    
            temp1.plot(kind = 'scatter', x = col, y = 'price' , 
                           ax = ax, color = 'DarkBlue', s= .02 * auto_prices['engine-size'] * auto_prices['engine-size'], 
                       alpha = 0.3)                          
        if temp2.shape[0] > 0:                    
            temp2.plot(kind = 'scatter', x = col, y = 'price' , 
                           ax = ax, color = 'Red', s= .02 * auto_prices['engine-size']  * auto_prices['engine-size'], 
                       alpha = 0.3) 
    ax.set_title('Scatter plot of price vs. ' + col + ' with engine size')
    red_patch = mpatches.Patch(color='Red', label='Diesel')   
    blue_patch = mpatches.Patch(color='DarkBlue', label='Gas')
    plt.legend(handles=[red_patch, blue_patch])
    return 'Done'
auto_size_2(auto_prices, ['city-mpg']) 

# Notice that the differences in __________ are much more apparent when we use area to determine marker size.
# Out:
# 'Done'

# %% [markdown]
# ### Using marker shapes
#
# Typically, different marker shapes are used to indicate the categories of a categorical variable.
#
# The code in the cell below uses different marker shapes to indicate ... and ... .

# %%
def auto_shape(df):
    import matplotlib.pyplot as plt
    import matplotlib.lines as mlines
    aspiration = ['turbo', 'turbo', 'std', 'std']
    fuel = ['diesel', 'gas', 'diesel', 'gas']
    # n e w :
    mrks = ['o', 'o', '+', '+']
    cols = ['Red', 'DarkBlue', 'Red', 'DarkBlue']
    # n e w :
    ldg = []
    fig = plt.figure(figsize=(6,6))
    ax = fig.gca()
    # n e w : zip and mlines.Line2D
    for asp, fl, mk, cl in zip(aspiration, fuel, mrks, cols):
        temp = df.ix[(df['aspiration'] == asp) & (df['fuel-type'] == fl)]       
        if temp.shape[0] > 0:                    
            temp.plot(kind = 'scatter', x = 'city-mpg', y = 'price' , ax = ax, color = cl, marker = mk,
                       s= .02 * df['engine-size'] * df['engine-size'], alpha = 0.5)    
        ldg.append(mlines.Line2D([], [], color=cl, marker=mk, markersize=10, 
                                 label=(asp + ' and ' + fl)))    
    ax.set_title('Scatter plot of price vs. city mpg with marker size = engine size')
    plt.legend(handles=ldg)
    return'Done'
auto_shape(auto_prices)
# Out:
# 'Done'

# %% [markdown]
# ### Plot specific aesthetics - Histogram bins

# %%
# changing the number of bins in a histogram

fig, ax = plt.subplots(1, 2, figsize = (16, 6))
auto_prices['engine-size'].plot.hist(ax = ax[0]) 
ax[0].set_title('Histogram of auto engine size with 10 bins') # Give the plot a main title
ax[0].set_xlabel('Engine size') # Set text for the x axis
ax[0].set_ylabel('Number of autos')# Set text for y axis
auto_prices['engine-size'].plot.hist(ax = ax[1], bins = 40) 
ax[1].set_title('Histogram of auto engine size with 40 bins') 
ax[1].set_xlabel('Engine size') 
ax[1].set_ylabel('Number of autos')

# %% [markdown]
# ### Plot specific aesthetics - Split violin plot
#
# The violin plots supported in Seaborn, allow you to group the data by a binary categorical variable. In the code shown below, the ``hue`` argument is used to show the KDEs of ... and ... (standard and turbo aspiration cars), for grouped by the ``x`` axis variable of ... (fuel type). The resulting plot shows three dimensions: ... (price, fuel type and aspiration).

# %%
import seaborn as sns
sns.set_style("whitegrid")
sns.violinplot(data = auto_prices, x = 'fuel-type', y = 'price', hue="aspiration",  split=True)

# %% [markdown]
# ### Plot specific aesthetics - Box plots
#
# Using Seaborn we can add group data for box plots by ``hue``, much as we just did with violin plots. The code below uses the ``hue`` aesthetic to group the ... (cars) by body style. As before, the ``x`` axis groups the ... (autos) by ... (fuel type).

# %%
sns.set_style("whitegrid")
sns.boxplot(data = auto_prices, x = 'fuel-type', y = 'price', hue="body-style")

# %%
"""YOU: 
Try the following:
    Create a new code cell below.
    Copy the code used for the previous violin plot into the new cell.
    Change the x group by variable (from fuel-type) to 'drive-wheels'.
    Examine the resulting plot. What new information is now apparent?
"""

import seaborn as sns
sns.set_style("whitegrid")
sns.violinplot(data = auto_prices, x = 'drive-wheels', y = 'price', hue="aspiration",  split=True)

# %% [markdown]
# ## Multi-axis and Facet Plots
#
# ...Faceting involves using values of categorical or numeric variables to create a systematic grid of related plots. Faceting goes by several other monikers, including conditioned plotting or lattice plotting.

# %% [markdown]
# ### Pair wise plots
#
# also know as plot matrices,
#
# A scatter plot is shown of each variable versus all other variables, arranged in an array.
#
# Another type of plot, such as a KDE plot, can be shown for each pair of variables.
#
# Other plot types can be placed along the diagonal of the array.
#
# Code to create a pair wise scatter plot for certain variables in the ... (auto price) data set is shown in the cell below. The recipe is:
#
# - Define a list of the columns we wish to display.
# - Use the Seaborn ``pairplot`` method to display the pairwise scatter plots of the subset of the pandas data frame or numpy array. The ``map_upper`` method is used to add KDE plots to the upper part of the plot array.
# - An argument to ``pairplot`` defines a color palette.
# - An argument to ``pairplot`` defines KDE plots be placed along the diagonal of the array.

# %%
num_cols = ["length", "curb-weight", "engine-size", "horsepower", "city-mpg", "price", "fuel-type"] 
sns.pairplot(auto_prices[num_cols], hue='fuel-type', palette="Set2", diag_kind="kde", 
             size=2).map_upper(sns.kdeplot, cmap="Blues_d")

# %% [markdown]
# ### Facet plots
#
# In many cases grouping a data set by other variables before plotting is a useful way to understand complex relationships The Seaborn package allows us to create faceted plots that do just this.
#
# The code in the cell below does just this, following this recipe:
#
# - A ``FacetGrid`` is defined for the data set. In this case we have only one facet (group by variable), across columns.
# - The ``map`` method is applied to the facet grid with a plot type specified.
# - In this case, the the plot type uses the ``distplot`` method to create a scatter plot.

# %%
g = sns.FacetGrid(auto_prices, col="drive-wheels")
g.map(sns.distplot, "price")

# %%
# The code in the cell below extends our recipe to include a second dimension for our facet grid. 
# Both a row and col agrument are specified for the FacetGrid method.

# %%
g = sns.FacetGrid(auto_prices, col="fuel-type", row = "aspiration")
g.map(sns.distplot, "price")

# %%
# The code in the cell below plots a grid of scatterplots using drive wheels and body style as the facet variables. 
# Execute this code and examine the result.

# %%
g = sns.FacetGrid(auto_prices, col="drive-wheels", row = 'body-style')
g.map(sns.regplot, "city-mpg", "price", fit_reg = False)

# %% [markdown]
# ### Facet plots with aesthetics
#
# The code in the cell below uses the ``hue`` argument to the ``FacetGrid`` method to add a fifth dimension to the scatter plot array.

# %%
g = sns.FacetGrid(auto_prices, col="drive-wheels", row = 'body-style', 
                  hue = 'fuel-type',  palette="Set2")
g.map(sns.regplot, 'city-mpg', 'price', fit_reg = False)

# %%
"""You:
Do the following:
    Create a new code cell below.
    Copy the code used for the previous example into the new cell.
    Change the x axis variable to 'city-mpg'. No, horsepower, engine-size, curb-length, weight
    Examine the resulting plot. What new information is now apparent?
"""

#g = sns.FacetGrid(auto_prices, col="drive-wheels", row = 'body-style', 
g = sns.FacetGrid(auto_prices, col="drive-wheels", row = 'body-style', 
                  hue = 'fuel-type',  palette="Set2")
g.map(sns.regplot, 'horsepower', 'price', fit_reg = False)

# %% [markdown]
# # Lab04: Visualizing Data
# ## Exercise 1: Visualizing Automobile Data for Regression

# %%
# %matplotlib inline
import pandas as pd
import numpy as np

"""from azureml import Workspace
ws = Workspace()
ds = ws.datasets['Automobile price data (Raw)']
auto_price = ds.to_dataframe()"""

auto_price = pd.read_csv('Automobile price data _Raw_.csv')
# the file is downloaded from https://studio.azureml.net/ to the same folder where this notebook is stored, on C: drive.

## Convert some columns to numeric values
cols = ['price', 'bore', 'stroke', 'horsepower', 'peak-rpm']
auto_price[cols] = auto_price[cols].apply(pd.to_numeric, args=('coerce',))

## Remove rows with missing values
auto_price.dropna(axis = 0, inplace = True)

## Compute the log of the auto price
auto_price['lnprice'] = np.log(auto_price.price)

## Create a column with new levels for the number of cylinders
auto_price['num-cylinders'] = ['four-or-less' if x in ['two', 'three', 'four'] else 
    ('five-six' if x in ['five', 'six'] else 
    'eight-twelve') for x in auto_price['num-of-cylinders']]

print(auto_price.dtypes)
auto_price.head(5)
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# lnprice              float64
# num-cylinders         object
# dtype: object
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# ...

# %% [markdown]
# ### Create a Pair-Wise Scatter Plot

# %%
import seaborn as sns
num_cols = ["length", "curb-weight", "engine-size", "horsepower", "city-mpg", "price", "fuel-type"] 
sns.pairplot(auto_price[num_cols], size=2)

# %% [markdown]
# ### Create Histograms

# %%
## Function to plot conditioned histograms
def cond_hists(df, plot_cols, grid_col):
    import matplotlib.pyplot as plt
    import seaborn as sns
    ## Loop over the list of columns
    for col in plot_cols:
        grid1 = sns.FacetGrid(df, col=grid_col)
        grid1.map(plt.hist, col, alpha=.7)
    return grid_col

## Define columns for making a conditioned histogram
plot_cols2 = ["length",
               "curb-weight",
               "engine-size",
               "city-mpg",
               "price"]

cond_hists(auto_price, plot_cols2, 'drive-wheels')
# Out:
# 'drive-wheels'

# %% [markdown]
# ### Create Box Plots

# %%
## Create boxplots of data
def auto_boxplot(df, plot_cols, by):
    import matplotlib.pyplot as plt
    for col in plot_cols:
        fig = plt.figure(figsize=(9, 6))
        ax = fig.gca()
        df.boxplot(column = col, by = by, ax = ax)
        ax.set_title('Box plots of ' + col + ' by ' + by)
        ax.set_ylabel(col)
    return by 

auto_boxplot(auto_price, plot_cols2, "drive-wheels")
# Out:
# 'drive-wheels'

# %% [markdown]
# ### Create Scatter Plots

# %%
## Create scatter plot
def auto_scatter(df, plot_cols):
    import matplotlib.pyplot as plt
    for col in plot_cols:
        fig = plt.figure(figsize=(8, 8))
        ax = fig.gca()
        temp1 = df.ix[df['fuel-type'] == 'gas']       
        temp2 = df.ix[df['fuel-type'] == 'diesel']
        if temp1.shape[0] > 0:                    
            temp1.plot(kind = 'scatter', x = col, y = 'price' , 
                           ax = ax, color = 'DarkBlue')                          
        if temp2.shape[0] > 0:                    
            temp2.plot(kind = 'scatter', x = col, y = 'price' , 
                           ax = ax, color = 'Red') 
        ax.set_title('Scatter plot of price vs. ' + col)
    return plot_cols

## Define columns for making scatter plots
plot_cols3 = ["length",
               "curb-weight",
               "engine-size",
               "city-mpg"]

auto_scatter(auto_price, plot_cols3)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#   import sys
# ['length', 'curb-weight', 'engine-size', 'city-mpg']

# %% [markdown]
# ### Create Conditioned Scatter Plots

# %%
def cond_plot(cols):
    import IPython.html.widgets
    import seaborn as sns
    for col in cols:
        g = sns.FacetGrid(auto_price, col="num-cylinders", row = 'body-style', 
                      hue="fuel-type", palette="Set2", margin_titles=True)
        g.map(sns.regplot, col, "price", fit_reg = False)
#        g.map(sns.regplot, "engine-size", "price", fit_reg = False)
cond_plot(plot_cols3)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\html.py:14: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %% [markdown]
# ## Exercise 2:  Visualizing Adult Census Data for Classification

# %% [markdown]
# ### Load the Adult Census Data

# %%
# %matplotlib inline
import pandas as pd
import numpy as np

"""from azureml import Workspace
ws = Workspace()
ds = ws.datasets['Adult Census Income Binary Classification dataset']
Income = ds.to_dataframe()
"""

Income = pd.read_csv('Adult Census Income Binary Classification dataset.csv')
# the file is downloaded from https://studio.azureml.net/ to the same folder where this notebook is stored, on C: drive.

print(Income.dtypes)
Income.head(5)
# Out:
# age                 int64
#  workclass         object
#  fnlwgt             int64
#  education         object
#  education-num      int64
#  marital-status    object
#  occupation        object
#  relationship      object
#  race              object
#  sex               object
#  capital-gain       int64
#  capital-loss       int64
#  hours-per-week     int64
#  native-country    object
#  income            object
# dtype: object
#    age          workclass   fnlwgt   education   education-num  \
# 0   39          State-gov    77516   Bachelors              13
# 1   50   Self-emp-not-inc    83311   Bachelors              13
# 2   38            Private   215646     HS-grad               9
# 3   53            Private   234721        11th               7
# 4   28            Private   338409   Bachelors              13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# ...

# %% [markdown]
# ### Bar Plot the Categorical Features

# %%
## Plot categorical variables as bar plots
def income_barplot(df):
    import numpy as np
    import matplotlib.pyplot as plt
#    print(df.columns.tolist())   # for debugging.
    cols = df.columns.tolist()[:-1]
    for col in cols:
        if(df.loc[:, col].dtype not in [np.int64, np.int32, np.float64]):  # not numeric; changed .ix to .loc
#            print('COL=', col)   # debugging
            # print('DF=', df[col])   # debugging
            # df[' income']   # debugging
            # .value_counts()   , counts by category of a variable
            temp1 = df.ix[df[' income'] == ' <=50K', col].value_counts()   # ' income' instead 'income'; ' <=50K' instead '<=50K'; can change .ix to .loc,
            temp0 = df.ix[df[' income'] == ' >50K', col].value_counts() 
            # print('TEMP1= ', temp1)   # debugging
            # print('TEMP1.value_counts()= ', temp1.value_counts())
            ylim = [0, max(max(temp1), max(temp0))]
#            print('MAX_TEMP1=', max(temp1))   # debugging
#            print('MAX_TEMP0=', max(temp0))   # debugging
            fig = plt.figure(figsize = (12,6))
            fig.clf()
            ax1 = fig.add_subplot(1, 2, 1)
            ax0 = fig.add_subplot(1, 2, 2) 
            temp1.plot(kind = 'bar', ax = ax1, ylim = ylim)
            ax1.set_title('Values of ' + col + '\n for income <= 50K')
            temp0.plot(kind = 'bar', ax = ax0, ylim = ylim)
            ax0.set_title('Values of ' + col + '\n for income > 50K')
    return('Done')        

# print(Income.head(2))

income_barplot(Income)
# Out:
# 'Done'

# %% [markdown]
# ### Box Plot the Numeric Features
#
# for each numeric feature, conditioned on the label ("income") value (2 categories: <= or >50k). By examining these box plots, you will determine which features are likely to be useful as predictors of the label ("income") CATEGORIES (<= or >50k).

# %%
## Plot categorical(?) variables as box plots
def income_boxplot(df):
    import numpy as np
    import matplotlib.pyplot as plt
    
    cols = df.columns.tolist()[:-1]
#    print('COLS=', cols)
    for col in cols:
        if(df[col].dtype in [np.int64, np.int32, np.float64]):                  # is numeric feature.
            fig = plt.figure(figsize = (6,6))
            fig.clf()
            ax = fig.gca() 
            df.boxplot(column = [col], ax = ax, by = [' income'])   # ' income' instead 'income'          
    return('Done') 

# print(Income.head())
income_boxplot(Income)

# (Note that education.num may have some power in predicting the label category. People with income >50K tend to have consistently higher education.num values than people with income <=50K.)
# Out:
#    age          workclass   fnlwgt   education   education-num  \
# 0   39          State-gov    77516   Bachelors              13
# 1   50   Self-emp-not-inc    83311   Bachelors              13
# 2   38            Private   215646     HS-grad               9
# 3   53            Private   234721        11th               7
# 4   28            Private   338409   Bachelors              13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#     capital-gain   capital-loss   hours-per-week  native-country  income
# ...

# %% [markdown]
# ### Video 44, Plotting with Python in Azure ML Experiments

# %%
def azureml_main2(auto_price):
    import numpy as np
    import matplotlib.pyplot as plt

    ## Create subsets to the data
    temp1 = auto_price[auto_price['aspiration'] == 'std']
    temp2 = auto_price[auto_price['aspiration'] == 'turbo']

    ## Create scatter plot for each subset
    import matplotlib.pyplot as plt
    fig = plt.figure(figsize= (6,6))
    ax = fig.gca()
    temp1.plot(kind = 'scatter', x = 'length', y = 'price', ax = ax, color = 'DarkBlue')
    temp2.plot(kind = 'scatter', x = 'length', y = 'price', ax = ax, color = 'Red')
    ax.set_title('Scatter plot of Price vs. Length with color by Aspirations')
    # missing legend on the chart
    fig.savefig('auto-plot.png')   # the .png file is saved into current directory (where this notebook is stored)
    return auto_price


azureml_main2(auto_price)
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# 5            2                 ?         audi       gas        std
# 6            1               158         audi       gas        std
# 7            1                 ?         audi       gas        std
# 8            1               158         audi       gas      turbo
# 10           2               192          bmw       gas        std
# 11           0               192          bmw       gas        std
# 12           0               188          bmw       gas        std
# 13           0               188          bmw       gas        std
# ...

# %%
import pandas as pd
auto_price = pd.read_csv('Automobile price data _Raw_.csv')
# the file is downloaded from https://studio.azureml.net/ to the same folder where this notebook is stored, on C: drive.
auto_price.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...    engine-size  \
# 0  convertible          rwd           front        88.6  ...            130
# 1  convertible          rwd           front        88.6  ...            130
# 2    hatchback          rwd           front        94.5  ...            152
# 3        sedan          fwd           front        99.8  ...            109
# 4        sedan          4wd           front        99.4  ...            136
#
# ...

# %%
auto_price['body-style'].head()
auto_price['body-style'].value_counts()
# Out:
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: body-style, dtype: int64
